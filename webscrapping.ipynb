# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"redmi"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=redmi'

# %%
urlClient = uReq(flipcart_url)

# %%
urlClient

# %%
flipcart_page = urlClient.read()

# %%
flipcart_html = bs(flipcart_page, 'html.parser')

# %%
flipcart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigBox = flipcart_html.findAll("div", {"class": "cPHDOP col-12-12"})

# %%
len(bigBox)
# Out:
# 30

# %%
del bigBox[0:3]

# %%
productLink = "https://www.flipkart.com"+bigBox[3].div.div.div.a['href']

# %%
product_req = requests.get(productLink)

# %%
productLink
# Out:
# 'https://www.flipkart.com/redmi-12-5g-jade-black-128-gb/p/itma9b37bec7de7e?pid=MOBGS7GYGUAJ4UYZ&lid=LSTMOBGS7GYGUAJ4UYZOAPCWA&marketplace=FLIPKART&q=redmi&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=4b869f8f-a513-403c-bac1-110e0bf94fe5.MOBGS7GYGUAJ4UYZ.SEARCH&ppt=None&ppn=None&ssid=dgrjjrbwao0000001714807937267&qH=9b6bf0057c19bd94'

# %%
product_req
# Out:
# <Response [200]>

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
reviewBox = product_html.findAll("div", {"class": "RcXBOT"})

# %%
len(reviewBox)
# Out:
# 11

# %%
reviewBox[0].div.div.find("p", {"class": "_2NsDsF AwS1CA"}).text
# Out:
# 'Abdul Rahaman Mandal'

# %%
for i in reviewBox:
    print(i.div.div.find("p", {"class": "_2NsDsF AwS1CA"}).text)
# Out:
# Abdul Rahaman Mandal
# MIRZA KAZIM Ali BAIG
# Rakesh Sarkar
# Sushil Rajput
# Vishakha  Singh
# RAVI KUMAR MAHATO
# Vivek  Barve
# Flipkart Customer
# Jitendra Kumar
# Abhishek  Singh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 2
#       1 for i in reviewBox:
# ----> 2     print(i.div.div.find("p", {"class": "_2NsDsF AwS1CA"}).text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviewBox[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in reviewBox:
    print(i.div.div.div.div.text)
# Out:
# 5
# 4
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 2
#       1 for i in reviewBox:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviewBox[0].div.div.div.p.text
# Out:
# 'Terrific'

# %%
for i in reviewBox:
    print(i.div.div.div.p.text)
# Out:
# Terrific
# Nice product
# Good
# Excellent
# Not good
# Worth every penny
# Must buy!
# Fabulous!
# Excellent
# Terrific purchase
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 2
#       1 for i in reviewBox:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviewBox[0].div.div.find("div", {"class": "ZmyHeo"}).div.div.text
# Out:
# 'Good 👍'

# %%
for i in reviewBox:
    print(i.div.div.find("div", {"class": "ZmyHeo"}).div.div.text)
# Out:
# Good 👍
# Nice phone for normal uses fancy design .Front cemra is only 8 megapixel, plz
# Good product battery performance is not so good feet is 👌okay
# Awesome and good look
# Sound quality is not good
# Very good mobile 😄😍
# Product is very good.. battery backup nice... Camera quality awesome..
# Good
# Realme 12 5G nice model
# Over all all-round smart phone..
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 2
#       1 for i in reviewBox:
# ----> 2     print(i.div.div.find("div", {"class": "ZmyHeo"}).div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in bigBox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/redmi-12-5g-jade-black-128-gb/p/itmb7b9567637d5c?pid=MOBGS9QU7QVWUWRD&lid=LSTMOBGS9QU7QVWUWRDWPHNEP&marketplace=FLIPKART&q=redmi&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=en_9Rt6kggU8pi1qBmBdGcARo34ZgfFU6U0Xt0L2yKjdZj7TOIGgivzALY9zrGlZYz9LyBpkEG8--61Xf49VpLzyvUFjCTyOHoHZs-Z5_PS_w0%3D&ppt=None&ppn=None&ssid=dgrjjrbwao0000001714807937267&qH=9b6bf0057c19bd94
# https://www.flipkart.com/redmi-12-5g-pastel-blue-128-gb/p/itm78076aae16588?pid=MOBGS7K3BFTXMMGG&lid=LSTMOBGS7K3BFTXMMGGHGLY9K&marketplace=FLIPKART&q=redmi&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=4b869f8f-a513-403c-bac1-110e0bf94fe5.MOBGS7K3BFTXMMGG.SEARCH&ppt=None&ppn=None&ssid=dgrjjrbwao0000001714807937267&qH=9b6bf0057c19bd94
# ...
